# %% [markdown]
# # Data Science Pandas

# %% [markdown]
# ## Tasks Today:
#
# 0) <b>Pre-Work</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Numpy Random Sampling
#
# 1) <b>Pandas</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Tabular Data Structures <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - from_dict() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - read_csv() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Accessing Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Indexing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.loc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - keys() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Slicing a DataFrame <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Built-In Methods <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - head() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - tail() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - shape <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - describe() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - sort_values() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - .columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Filtration <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Conditionals <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subsetting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Column Transformations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Generating a New Column w/Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - User Defined Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Aggregations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Type of groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - mean() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() w/Multiple Columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - drop_duplicates() <br>

# %% [markdown]
# ## Numpy Random Sampling

# %%
import numpy as np

# A single call generates a single random number
print('Here is a random number: %s' % np.random.uniform())

# You can also pass some bounds
print('Here is a random number between 0 and 1 Million: %s' % np.random.uniform(0, 1e6))

# You can also generate a bunch of random numbers all at once
print('Here are 3 random numbers between 0 and 1 Million: %s' % np.random.uniform(0, 1e6, 3))

# Even matrices and tensors with weird shapes
print('Here is a 3x3 matrix of random numbers between 0 and 1 Million: \n %s' % np.random.uniform(0, 1e6, (3, 3)))

# instead of float values, generating random integers
print('Using Random Integer: %s' % np.random.randint(0, 10, 4))
# Out:
# Here is a random number: 0.541954275718229
# Here is a random number between 0 and 1 Million: 112233.47083912083
# Here are 3 random numbers between 0 and 1 Million: [485247.88146449 875762.65196515 520582.46399477]
# Here is a 3x3 matrix of random numbers between 0 and 1 Million:
#  [[152573.7222078  261732.40448015 810318.98103841]
#  [848569.01486138  74234.50182835 776158.68984903]
#  [161198.66036385 214745.26926388 230247.20903378]]
# Using Random Integer: [3 5 8 9]

# %% [markdown]
# ## Pandas <br>
#
# <p>Pandas is a flexible data analysis library built on top of NumPy that is excellent for working with tabular data. It is currently the de-facto standard for Python-based data analysis, and fluency in Pandas will do wonders for your productivity and frankly your resume. It is one of the fastest ways of getting from zero to answer in existence. </p>
#
# <ul>
#     <li>Pandas is a Python module, written in C. The Pandas module is a high performance, highly efficient, and high level data analysis library. It allows us to work with large sets of data called dataframes.</li>
#     <li>Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)</li>
#     <li>Dataframe = Spreadsheet (has column headers, index, etc.)</li>
# </ul>

# %% [markdown]
# ### Importing

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\idamc\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\idamc\anaconda3\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\idamc\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\idamc\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\idamc\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %%
import pandas as pd

# always use pd, standard for data science

# %% [markdown]
# ### Tabular data structures <br>
# <p>The central object of study in Pandas is the DataFrame, which is a tabular data structure with rows and columns like an excel spreadsheet. The first point of discussion is the creation of dataframes both from native Python dictionaries, and text files through the Pandas I/O system.</p>

# %%
names = ['Alice',
         'Bob',
         'James',
         'Beth', 
         'John', 
         'Sally',
         'Richard', 
         'Lauren',
         'Brandon', 
         'Sabrina']

names = ['Alice',
         'Bob',
         'James',
         'Beth', 
         'John', 
         'Sally',
         'Richard', 
         'Lauren',
         'Brandon', 
         'Sabrina']
ages = np.random.randint(18,35,len(names))
my_people = {
    'names': names,
    'ages': ages
}
my_people
# Out:
# {'names': ['Alice',
#   'Bob',
#   'James',
#   'Beth',
#   'John',
#   'Sally',
#   'Richard',
#   'Lauren',
#   'Brandon',
#   'Sabrina'],
#  'ages': array([28, 21, 34, 22, 25, 34, 24, 20, 33, 23])}

# %% [markdown]
# 2             3      3  12/30/1899 1:04:36 AM    M             Osako, Suguru
# 3             4      4  12/30/1899 1:04:45 AM    M          Biwott, Shadrack
# 4             5      5  12/30/1899 1:04:35 AM    M            Chebet, Wilson
# ...         ...    ...                    ...  ...                       ...
# 26405       344  11972  12/30/1899 3:23:31 AM    F  Steinbach, Paula Eyvonne
# 26406      4774  14436  12/30/1899 3:00:26 AM    M        Avelino, Andrew R.
# 26407       698  11973  12/30/1899 3:36:24 AM    F           Hantel, Johanna
# 26408      1043  14437  12/30/1899 3:22:30 AM    M              Reilly, Bill
# 26409      2553  14438  12/30/1899 3:08:16 AM    M             Rigsby, Scott
#
#       Number of Records          Official Time  Overall  \
# 0                     1  12/30/1899 2:09:37 AM        1
# 1                     1  12/30/1899 2:09:58 AM        2
# 2                     1  12/30/1899 2:10:28 AM        3
# 3                     1  12/30/1899 2:12:08 AM        4
# 4                     1  12/30/1899 2:12:35 AM        5
# ...                 ...                    ...      ...
# 26405                 1  12/30/1899 7:09:39 AM    26407
# 26406                 1  12/30/1899 7:16:59 AM    26408
# 26407                 1  12/30/1899 7:19:37 AM    26409
# 26408                 1  12/30/1899 7:20:44 AM    26410
# 26409                 1  12/30/1899 7:58:14 AM    26411
#
#                          Pace State
# 0      12/30/1899 12:04:57 AM   NaN
# 1      12/30/1899 12:04:58 AM    OR
# 2      12/30/1899 12:04:59 AM   NaN
# 3      12/30/1899 12:05:03 AM    CA
# 4      12/30/1899 12:05:04 AM   NaN
# ...                       ...   ...
# 26405  12/30/1899 12:16:24 AM    CA
# 26406  12/30/1899 12:16:40 AM    NC
# 26407  12/30/1899 12:16:47 AM    PA
# 26408  12/30/1899 12:16:49 AM    NY
# 26409  12/30/1899 12:18:15 AM    GA
#
# [26410 rows x 26 columns]

# %% [markdown]
# ### In-Class Exercise #1 - Read in Boston Red Sox Hitting Data <br>
# <p>Use the pandas read_csv() method to read in the statistics from the two files yesterday.</p>

# %%
boston17 = pd.read_csv('../files/redsox_2017_hitting.txt', sep = ',')
boston18 = pd.read_csv('../files/redsox_2018_hitting.txt', sep = ',')

boston17
# Out:
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B  ...    OBP  \
# 0    1   C   Christian Vazquez   26   99  345  324   43   94  18  ...  0.330
# 1    2  1B      Mitch Moreland   31  149  576  508   73  125  34  ...  0.326
# 2    3  2B      Dustin Pedroia   33  105  463  406   46  119  19  ...  0.369
# 3    4  SS     Xander Bogaerts   24  148  635  571   94  156  32  ...  0.343
# 4    5  3B       Rafael Devers   20   58  240  222   34   63  14  ...  0.338
# 5    6  LF   Andrew Benintendi   22  151  658  573   84  155  26  ...  0.352
# 6    7  CF  Jackie Bradley Jr.   27  133  541  482   58  118  19  ...  0.323
# 7    8  RF        Mookie Betts   24  153  712  628  101  166  46  ...  0.344
# 8    9  DH      Hanley Ramirez   33  133  553  496   58  120  24  ...  0.320
# 9   10   C          Sandy Leon   28   85  301  271   32   61  14  ...  0.290
# 10  11  UT         Chris Young   33   90  276  243   30   57  12  ...  0.322
# 11  12  3B       Deven Marrero   26   71  188  171   32   36   9  ...  0.259
# 12  13  2B       Eduardo Nunez   30   38  173  165   23   53  12  ...  0.353
# 13  14  2B          Brock Holt   29   64  164  140   20   28   6  ...  0.305
# 14  15  IF       Josh Rutledge   28   37  118  107   10   24   2  ...  0.297
# 15  16  3B      Pablo Sandoval   30   32  108   99   10   21   2  ...  0.269
# 16  17  UT          Sam Travis   23   33   83   76   13   20   6  ...  0.325
# 17  18  UT         Tzu-Wei Lin   23   25   66   56    7   15   0  ...  0.369
# 18  19  IF     Marco Hernandez   24   21   60   58    7   16   3  ...  0.300
# 19  20  UT         Rajai Davis   36   17   38   36    7    9   2  ...  0.289
# 20  21  UT        Steve Selsky   27    8    9    9    0    1   1  ...  0.111
# 21  22  UT       Blake Swihart   25    6    7    5    1    1   0  ...  0.429
# 22  23  2B      Chase d'Arnaud   30    2    1    1    2    1   0  ...  1.000
#
#       SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0   0.404  0.735    91  131   14    3   0   1    0
# 1   0.443  0.769    99  225   14    6   0   5    6
# 2   0.392  0.760   100  159   11    2   2   4    4
# 3   0.403  0.746    95  230   17    6   0   2    6
# 4   0.482  0.819   111  107    5    0   0   0    3
# 5   0.424  0.776   102  243   16    6   1   8    7
# 6   0.402  0.726    89  194    8    9   0   2    4
# 7   0.459  0.803   108  288    9    2   0   5    9
# 8   0.429  0.750    94  213   15    6   0   0    8
# 9   0.354  0.644    68   96    5    1   1   3    1
# 10  0.387  0.709    85   94    4    2   0   1    0
# 11  0.333  0.593    54   57    8    0   3   2    0
# 12  0.539  0.892   128   89    3    2   0   0    0
# 13  0.243  0.548    47   34    3    3   0   2    0
# 14  0.262  0.558    49   28    1    2   0   0    0
# 15  0.354  0.622    61   35    4    0   0   1    0
# 16  0.342  0.667    75   26    2    1   0   0    0
# 17  0.339  0.709    88   19    0    0   1   0    0
# 18  0.328  0.628    65   19    0    1   0   0    0
# 19  0.306  0.595    56   11    2    1   0   0    0
# 20  0.222  0.333   -16    2    0    0   0   0    0
# 21  0.200  0.629    74    1    0    0   0   0    0
# 22  1.000  2.000   428    1    0    0   0   0    0
#
# [23 rows x 28 columns]

# %% [markdown]
# ### Accessing Data <br>

# %% [markdown]
# ##### Indexing
#
# <p>You can directly select a column of a dataframe just like you would a dict. The result is a Pandas 'Series' object.</p>

# %%
data_ages = data['ages']

#print out the type of the variable data
print(type(data_ages)) # series 
print(type(data)) # DataFrame

print(data_ages)
#short hand indexing
#key first, row/index second
#print(data['ages'][0:2])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# 0    28
# 1    21
# 2    34
# 3    22
# 4    25
# 5    34
# 6    24
# 7    20
# 8    33
# 9    23
# Name: ages, dtype: int32

# %% [markdown]
# ##### df.loc

# %% [markdown]
# <p>Along the horizontal dimension, rows of Pandas DataFrames are Row objects. You will notice there is a third column present in the DataFrame - this is the $\textit{index}$. It is automatically generated as a row number, but can be reassigned to a column of your choice using the DataFrame.set_index(colname) method. We can use it to access particular Pandas $\textit{rows}$, which are also Series objects:</p>

# %%
print(data)

# Grab the first row of data -- by the index of the row
my_first_row = data.loc[0]

print(f'\n Location of the first row in data: {my_first_row}')

# Reset our my_people dataframe index

reset_index = data.set_index('names')

print(reset_index)

reset_index.loc['James']
print(data.loc[2])
# Out:
#      names  ages
# 0    Alice    28
# 1      Bob    21
# 2    James    34
# 3     Beth    22
# 4     John    25
# 5    Sally    34
# 6  Richard    24
# 7   Lauren    20
# 8  Brandon    33
# 9  Sabrina    23
#
#  Location of the first row in data: names    Alice
# ages        28
# Name: 0, dtype: object
#          ages
# names
# Alice      28
# Bob        21
# James      34
# Beth       22
# John       25
# Sally      34
# Richard    24
# Lauren     20
# Brandon    33
# Sabrina    23
# names    James
# ages        34
# Name: 2, dtype: object

# %% [markdown]
# ##### keys()

# %%
# Access all of the keys/columns of the dataframe
# Dataframe.keys()
data.keys()

marathon.keys()
# Out:
# Index(['10K', '15K', '20K', '25K', '30K', '35K', '40K', '5K', 'Age', 'Bib',
#        'Overall Time in Seconds', 'Citizenship', 'Male Average Times',
#        'Females Average Times', 'City', 'Country', 'Division', 'Gender',
#        'Half', 'M/F', 'Name', 'Number of Records', 'Official Time', 'Overall',
#        'Pace', 'State'],
#       dtype='object')

# %% [markdown]
# ##### Slicing a DataFrame

# %%
print(data) # printing all data for context

print(data[2:5])
# Out:
#      names  ages
# 0    Alice    28
# 1      Bob    21
# 2    James    34
# 3     Beth    22
# 4     John    25
# 5    Sally    34
# 6  Richard    24
# 7   Lauren    20
# 8  Brandon    33
# 9  Sabrina    23
#    names  ages
# 2  James    34
# 3   Beth    22
# 4   John    25

# %% [markdown]
# ### Built-In Methods <br>
#
# <p>These are methods that are frequently used when using Pandas to make your life easier. It is possible to spend a whole week simply exploring the built-in functions supported by DataFrames in Pandas. Here however, we will simply highlight a few ones that might be useful, to give you an idea of what's possible out of the box with Pandas:</p>

# %% [markdown]
# ##### head()

# %%
# DataFrame.head()  --  Accepts integer parameterd (gives access to more rows)

marathon.head(10)
# Out:
#                       10K                     15K                    20K  \
# 0  12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 1  12/30/1899 12:30:27 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 2  12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:16 AM
# 3  12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:19 AM
# 4  12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 5  12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 6  12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 7  12/30/1899 12:30:28 AM  12/30/1899 12:46:13 AM  12/30/1899 1:02:35 AM
# 8  12/30/1899 12:30:29 AM  12/30/1899 12:45:47 AM  12/30/1899 1:01:28 AM
# 9  12/30/1899 12:30:30 AM  12/30/1899 12:45:47 AM  12/30/1899 1:01:28 AM
#
#                      25K                    30K                    35K  \
# 0  12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 1  12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 2  12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:31 AM
# 3  12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:58 AM
# 4  12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:41 AM
# 5  12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:52 AM
# 6  12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:49:06 AM
# 7  12/30/1899 1:18:36 AM  12/30/1899 1:34:52 AM  12/30/1899 1:51:11 AM
# 8  12/30/1899 1:17:26 AM  12/30/1899 1:34:05 AM  12/30/1899 1:50:53 AM
# 9  12/30/1899 1:17:17 AM  12/30/1899 1:33:49 AM  12/30/1899 1:50:44 AM
#
#                      40K                      5K  Age   Bib  ...  Division  \
# 0  12/30/1899 2:02:53 AM  12/30/1899 12:15:25 AM   24  11.0  ...         1
# 1  12/30/1899 2:03:14 AM  12/30/1899 12:15:24 AM   30  17.0  ...         2
# 2  12/30/1899 2:03:38 AM  12/30/1899 12:15:25 AM   25  23.0  ...         3
# 3  12/30/1899 2:04:35 AM  12/30/1899 12:15:25 AM   32  21.0  ...         4
# 4  12/30/1899 2:05:00 AM  12/30/1899 12:15:25 AM   31   9.0  ...         5
# 26409      2553  14438  12/30/1899 3:08:16 AM    M             Rigsby, Scott
#
#       Number of Records          Official Time  Overall  \
# 26400                 1  12/30/1899 6:47:14 AM    26402
# 26401                 1  12/30/1899 6:50:35 AM    26403
# 26402                 1  12/30/1899 6:52:10 AM    26404
# 26403                 1  12/30/1899 6:56:11 AM    26405
# 26404                 1  12/30/1899 7:04:33 AM    26406
# 26405                 1  12/30/1899 7:09:39 AM    26407
# 26406                 1  12/30/1899 7:16:59 AM    26408
# 26407                 1  12/30/1899 7:19:37 AM    26409
# 26408                 1  12/30/1899 7:20:44 AM    26410
# 26409                 1  12/30/1899 7:58:14 AM    26411
#
#                          Pace State
# 26400  12/30/1899 12:15:32 AM    FL
# 26401  12/30/1899 12:15:40 AM    IL
# 26402  12/30/1899 12:15:44 AM    AB
# 26403  12/30/1899 12:15:53 AM    FL
# 26404  12/30/1899 12:16:12 AM    MI
# 26405  12/30/1899 12:16:24 AM    CA
# 26406  12/30/1899 12:16:40 AM    NC
# 26407  12/30/1899 12:16:47 AM    PA
# 26408  12/30/1899 12:16:49 AM    NY
# 26409  12/30/1899 12:18:15 AM    GA
#
# [10 rows x 26 columns]

# %% [markdown]
# ##### shape

# %%
# The dataframe has a shape property, just like a NumPy matrix. 
# print(df.shape) -- Dataframe.shape -- No Parameter

marathon.shape
# Out:
# (26410, 26)

# %% [markdown]
# ##### describe() <br>
# <p>Probably one of the most important methods to understand...</p>

# %%
# Collect summary statistics in one line
# DataFrame.describe() -- Accepts parameters (all, exclude)

marathon.describe(include = 'all')
# Out:
#                            10K                    15K                    20K  \
# count                    26356                  26391                  26377
# unique                    2474                   3596                   4718
# top     12/30/1899 12:48:30 AM  12/30/1899 1:13:50 AM  12/30/1899 1:40:46 AM
# freq                        44                     29                     24
# mean                       NaN                    NaN                    NaN
# std                        NaN                    NaN                    NaN
# min                        NaN                    NaN                    NaN
# 25%                        NaN                    NaN                    NaN
# 50%                        NaN                    NaN                    NaN
# 75%                        NaN                    NaN                    NaN
# max                        NaN                    NaN                    NaN
#
#                           25K                    30K                    35K  \
# count                   26370                  26385                  26387
# unique                   5807                   6915                   7998
# top     12/30/1899 2:11:18 AM  12/30/1899 2:39:00 AM  12/30/1899 3:07:38 AM
# freq                       23                     18                     15
# mean                      NaN                    NaN                    NaN
# std                       NaN                    NaN                    NaN
# min                       NaN                    NaN                    NaN
# 25%                       NaN                    NaN                    NaN
# 50%                       NaN                    NaN                    NaN
# 75%                       NaN                    NaN                    NaN
# max                       NaN                    NaN                    NaN
#
#                           40K                      5K           Age  \
# count                   26404                   26385  26410.000000
# unique                   8943                    1326           NaN
# top     12/30/1899 3:32:23 AM  12/30/1899 12:24:38 AM           NaN
# freq                       14                      69           NaN
# mean                      NaN                     NaN     42.587732
# std                       NaN                     NaN     11.419467
# min                       NaN                     NaN     18.000000
# 25%                       NaN                     NaN     34.000000
# 50%                       NaN                     NaN     43.000000
# 75%                       NaN                     NaN     51.000000
# max                       NaN                     NaN     84.000000
#
#                  Bib  ...      Division        Gender                   Half  \
# count   26364.000000  ...  26410.000000  26410.000000                  26393
# unique           NaN  ...           NaN           NaN                   4920
# top              NaN  ...           NaN           NaN  12/30/1899 1:44:55 AM
# freq             NaN  ...           NaN           NaN                     26
# mean    15795.590844  ...   1588.796706   6660.973230                    NaN
# std      9109.945155  ...   1423.199500   3910.031525                    NaN
# min         3.000000  ...      1.000000      1.000000                    NaN
# 25%      8042.750000  ...    502.000000   3302.250000                    NaN
# 50%     16020.500000  ...   1154.000000   6603.500000                    NaN
# 75%     23473.250000  ...   2190.750000   9904.750000                    NaN
# max     31437.000000  ...   5846.000000  14438.000000                    NaN
#
#           M/F              Name Number of Records          Official Time  \
# count   26410             26410           26410.0                  26410
# unique      2             26365               NaN                   9269
# top         M  Burke, Patrick J               NaN  12/30/1899 4:13:37 AM
# freq    14438                 2               NaN                     13
# mean      NaN               NaN               1.0                    NaN
# std       NaN               NaN               0.0                    NaN
# min       NaN               NaN               1.0                    NaN
# 25%       NaN               NaN               1.0                    NaN
# 50%       NaN               NaN               1.0                    NaN
# 75%       NaN               NaN               1.0                    NaN
# max       NaN               NaN               1.0                    NaN
#
#              Overall                    Pace  State
# count   26410.000000                   26410  22815
# unique           NaN                     561     68
# top              NaN  12/30/1899 12:08:43 AM     MA
# freq             NaN                     157   4586
# mean    13206.260091                     NaN    NaN
# std      7624.370496                     NaN    NaN
# min         1.000000                     NaN    NaN
# 25%      6604.250000                     NaN    NaN
# 50%     13206.500000                     NaN    NaN
# 75%     19808.750000                     NaN    NaN
# max     26411.000000                     NaN    NaN
#
# [11 rows x 26 columns]

# %% [markdown]
# ##### sort_values()

# %%
# Sort based on many labels, with left-to-right priority
# sorted_data = data.sort_values('ages').reset_index()

# DataFrae.sort_values('key')

sorted_data = data.sort_values('ages', kind = 'mergesort')
sorted_data_reset = data.sort_values('ages', kind = 'mergesort').reset_index(drop=True)

sorted_data
# Out:
#      names  ages
# 7   Lauren    20
# 1      Bob    21
# 3     Beth    22
# 9  Sabrina    23
# 6  Richard    24
# 4     John    25
# 0    Alice    28
# 8  Brandon    33
# 2    James    34
# 5    Sally    34

# %% [markdown]
# ##### .columns

# %%
# will show all cols headers
# DataFrame.columns -- has no parameters

print(marathon.columns)
print(marathon.keys())
# Out:
# Index(['10K', '15K', '20K', '25K', '30K', '35K', '40K', '5K', 'Age', 'Bib',
#        'Overall Time in Seconds', 'Citizenship', 'Male Average Times',
#        'Females Average Times', 'City', 'Country', 'Division', 'Gender',
#        'Half', 'M/F', 'Name', 'Number of Records', 'Official Time', 'Overall',
#        'Pace', 'State'],
#       dtype='object')
# Index(['10K', '15K', '20K', '25K', '30K', '35K', '40K', '5K', 'Age', 'Bib',
#        'Overall Time in Seconds', 'Citizenship', 'Male Average Times',
#        'Females Average Times', 'City', 'Country', 'Division', 'Gender',
#        'Half', 'M/F', 'Name', 'Number of Records', 'Official Time', 'Overall',
#        'Pace', 'State'],
#       dtype='object')

# %% [markdown]
# ### In-Class Exercise #2 - Describe & Sort Boston Red Sox Hitting Data <br>
# <p>Take the data that you read in earlier from the Red Sox csv's and use the describe method to understand the data better. Compare the two years and decide which team is having the better year. Then sort the values based on Batting Average.</p>

# %%
ba17 = boston17.describe()['BA'].loc['mean']
ba18 = boston18.describe()['BA'].loc['mean']


if ba17 > ba18:
    print('Better year in 17')
else:
    print('Better year in 18')
# Out:
# Better year in 17

# %% [markdown]
# ### Filtration <br>
# <p>Let's look at how to filter dataframes for rows that fulfill a specific conditon.</p>

# %% [markdown]
# ##### Conditionals

# %%
# Conditional boolean dataframe
data['ages'] >= 25
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: ages, dtype: bool

# %% [markdown]
# ##### Subsetting

# %%
# exactly like numpy
data[data['ages'] >= 25 ]
# Out:
#      names  ages
# 0    Alice    28
# 2    James    34
# 4     John    25
# 5    Sally    34
# 8  Brandon    33

# %% [markdown]
# ### Column Transformations <br>
# <p>Rarely, if ever, will the columns in the original raw dataframe read from CSV or database table be the ones you actually need for your analysis. You will spend lots of time constantly transforming columns or groups of columns using general computational operations to produce new ones that are functions of the old ones. Pandas has full support for this: Consider the following dataframe containing membership term and renewal number for a group of customers:</p>

# %%
# Generate some fake data

customer_id = np.random.randint(1000,1100, 10)
renewal_nbr = np.random.randint(0,10,10)
customer_dict = {1: 0.5, 0: 1}
terms_in_years = [customer_dict[key] for key in np.random.randint(0,2,10)]

random_data = {
    'customer_id': customer_id,
    'renewal_nbr': renewal_nbr,
    'term_in_years': terms_in_years
}

customers = pd.DataFrame.from_dict(random_data)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years
# 0         1047            3            0.5
# 1         1003            8            1.0
# 2         1085            1            1.0
# 3         1072            8            0.5
# 4         1059            4            1.0
# 5         1013            0            1.0
# 6         1076            5            1.0
# 7         1095            3            1.0
# 8         1085            8            0.5
# 9         1012            9            1.0

# %% [markdown]
# ##### Generating a New Column w/Data

# %%
# DataFrane['key'] = Some calculatin from our dataframe column
customers['customer_tenure'] = customers['renewal_nbr'] * customers['term_in_years']
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure
# 0         1047            3            0.5              1.5
# 1         1003            8            1.0              8.0
# 2         1085            1            1.0              1.0
# 3         1072            8            0.5              4.0
# 4         1059            4            1.0              4.0
# 5         1013            0            1.0              0.0
# 6         1076            5            1.0              5.0
# 7         1095            3            1.0              3.0
# 8         1085            8            0.5              4.0
# 9         1012            9            1.0              9.0

# %% [markdown]
# ##### User Defined Function
#
# <p>If what you want to do to a column that can't be represented by simple mathematical operations, you can write your own $\textit{user defined function}$ with the full customizability available in Python and any external Python packages, then map it directly onto a column. Let's add some ages to our customer dataframe, and then classify them into our custom defined grouping scheme:</p>

# %%
# use .apply to map over dataframe

# Create a new column for ages

customers['ages'] = np.random.randint(18,70,10)

# User Defined Function -- Make Age Groups from our ages

def make_age_groups(age):
    if 10 <= age and 20 > age:
        return 'Teenager'
    elif 20 <= age and 35 > age:
        return 'Young Adult'
    elif 35 <= age and 65 > age:
        return 'Adult'
    elif 65 <= age:
        return 'Senior'
    
customers['age_group'] = customers['ages'].apply(make_age_groups)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1047            3            0.5              1.5    28
# 1         1003            8            1.0              8.0    69
# 2         1085            1            1.0              1.0    54
# 3         1072            8            0.5              4.0    53
# 4         1059            4            1.0              4.0    43
# 5         1013            0            1.0              0.0    37
# 6         1076            5            1.0              5.0    22
# 7         1095            3            1.0              3.0    60
# 8         1085            8            0.5              4.0    52
# 9         1012            9            1.0              9.0    59
#
#    loyalty_age_group    age_group
# 0          New Adult  Young Adult
# 1        Loyal Adult       Senior
# 2         New Senior        Adult
# 3  Loyal Young Adult        Adult
# 4        Loyal Adult        Adult
# 5       New Teenager        Adult
# 6  Loyal Young Adult  Young Adult
# 7        Loyal Adult        Adult
# 8       Loyal Senior        Adult
# 9  Loyal Young Adult        Adult

# %% [markdown]
# <p>As a last example I'll show here how you would use a lambda function to create a UDF that depends on $\textit{more than one}$ column:</p>
#
# <li>UDF = User Defined Function</li>

# %%
def make_loyalty_age_group(row):
    age = row['ages']
    tenure = row['customer_tenure']
    if 10 <= age and 20 > age:
        age_group = 'Teenager'
    elif 20 <= age and 35 > age:
        age_group = 'Young Adult'
    elif 35 <= age and 65 > age:
        age_group = 'Adult'
    elif 65 <= age:
        age_group = 'Senior'
    if tenure > 2.0:
        loyalty_age_group = 'Loyal ' + age_group
    else:
        loyalty_age_group = 'New ' + age_group
    return loyalty_age_group

customers['loyalty_age_group'] = customers.apply(make_loyalty_age_group, axis = 1)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1047            3            0.5              1.5    28
# 1         1003            8            1.0              8.0    69
# 2         1085            1            1.0              1.0    54
# 3         1072            8            0.5              4.0    53
# 4         1059            4            1.0              4.0    43
# 5         1013            0            1.0              0.0    37
# 6         1076            5            1.0              5.0    22
# 7         1095            3            1.0              3.0    60
# 8         1085            8            0.5              4.0    52
# 9         1012            9            1.0              9.0    59
#
#    loyalty_age_group    age_group
# 0    New Young Adult  Young Adult
# 1       Loyal Senior       Senior
# 2          New Adult        Adult
# 3        Loyal Adult        Adult
# 4        Loyal Adult        Adult
# 5          New Adult        Adult
# 6  Loyal Young Adult  Young Adult
# 7        Loyal Adult        Adult
# 8        Loyal Adult        Adult
# 9        Loyal Adult        Adult

# %% [markdown]
# ### In-Class Exercise #3 - Create Your Own UDF <br>
# <p>Using the Boston Red Sox data, create your own UDF which creates a new column called 'All-Star' and puts every player with either a batting average over .280 or an on base percentage of over .360 with a result of 'Yes' in the column and 'No' if not.</p>

# %%
"""
    Name  BA OBP AllStar
    --------------------
    Name .233 .360 Yes
    Name .150 .288 No
"""
def make_team(row):
    ba = row['BA']
    obp = row['OBP']
    
    if .280 > ba or .360 > obp:
        return 'Yes'
    else:
        return 'No'
    
boston17['Team'] = boston17.apply(make_team, axis = 1)
boston17[['Name', 'BA', 'OBP', 'Team']].loc[boston17['Team'] == 'Yes']
# Out:
#                   Name     BA    OBP Team
# 0    Christian Vazquez  0.290  0.330  Yes
# 1       Mitch Moreland  0.246  0.326  Yes
# 3      Xander Bogaerts  0.273  0.343  Yes
# 4        Rafael Devers  0.284  0.338  Yes
# 5    Andrew Benintendi  0.271  0.352  Yes
# 6   Jackie Bradley Jr.  0.245  0.323  Yes
# 7         Mookie Betts  0.264  0.344  Yes
# 8       Hanley Ramirez  0.242  0.320  Yes
# 9           Sandy Leon  0.225  0.290  Yes
# 10         Chris Young  0.235  0.322  Yes
# 11       Deven Marrero  0.211  0.259  Yes
# 12       Eduardo Nunez  0.321  0.353  Yes
# 13          Brock Holt  0.200  0.305  Yes
# 14       Josh Rutledge  0.224  0.297  Yes
# 15      Pablo Sandoval  0.212  0.269  Yes
# 16          Sam Travis  0.263  0.325  Yes
# 17         Tzu-Wei Lin  0.268  0.369  Yes
# 18     Marco Hernandez  0.276  0.300  Yes
# 19         Rajai Davis  0.250  0.289  Yes
# 20        Steve Selsky  0.111  0.111  Yes
# 21       Blake Swihart  0.200  0.429  Yes

# %% [markdown]
# ### Aggregations <br>
# <p>The raw data plus some transformations is generally only half the story. Your objective is to extract actual insights and actionable conclusions from the data, and that means reducing it from potentially billions of rows to some summary statistics via aggregation functions.</p>

# %% [markdown]
# ##### groupby() <br>
# <p>The .groupby() function is in some ways a 'master' aggregation.</p>
#
# <p>Data tables will usually reserve one column as a primary key - that is, a column for which each row has a unique value. This is to facilitate access to the exact rows of a data table that a user wants to view. The other columns will often have repeated values, such as the age groups in the above examples. We can use these columns to explore the data using the Pandas API:</p>

# %%
# also introducing .count() here, exact same as to how it's used in SQL

# Using the groupby with the column intact as a column/key
# customers.groupby('age_group', as_index = False).count()[['customer_id','age_group']]


# Using the groupby with the column as an index
group_all_customers = customers.groupby('age_group').count()

# Display only the Young Adult Info for customer_ids
group_all_customers.loc['Young Adult']

#Display both Young Adult and Senior Info
group_all_customers.loc[['Young Adult', 'Senior']]
# Out:
#              customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# age_group
# Young Adult            2            2              2                2     2
# Senior                 1            1              1                1     1
#
#              loyalty_age_group
# age_group
# Young Adult                  2
# Senior                       1

# %% [markdown]
# ##### Type of groupby()
#
# <p>The result is a new dataframe, the columns of which all contain the counts of the grouped field. Notice the type of a grouped dataframe:</p>

# %%
print(type(customers.groupby('age_group')))
print(type(customers))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <p>This is because simply grouping data doesn't quite make sense without an aggregation function like count() to pair with. In this case, we're counting occurances of the grouped field, but that's not all we can do. We can take averages, standard deviations, mins, maxes and much more! Let's see how this works a bit more:</p>

# %% [markdown]
# ##### mean()

# %%
# mean = average
customers.groupby('age_group').mean()
# Out:
#              customer_id  renewal_nbr  term_in_years  customer_tenure  \
# age_group
# Adult        1060.142857     4.714286       0.857143         3.571429
# Senior       1003.000000     8.000000       1.000000         8.000000
# Young Adult  1061.500000     4.000000       0.750000         3.250000
#
#                   ages
# age_group
# Adult        51.142857
# Senior       69.000000
# Young Adult  25.000000

# %% [markdown]
# ##### groupby() w/Multiple Columns
#
# <p>We end up with the average age of the groups in the last column, the average tenure in the tenure column, and so on and so forth. You can even split the groups more finely by passing a list of columns to group by:</p>

# %%
customers.groupby(['age_group', 'ages']).mean().sort_values('ages')
# Out:
#                   customer_id  renewal_nbr  term_in_years  customer_tenure
# age_group   ages
# Young Adult 22           1076            5            1.0              5.0
#             28           1047            3            0.5              1.5
# Adult       37           1013            0            1.0              0.0
#             43           1059            4            1.0              4.0
#             52           1085            8            0.5              4.0
#             53           1072            8            0.5              4.0
#             54           1085            1            1.0              1.0
#             59           1012            9            1.0              9.0
#             60           1095            3            1.0              3.0
# Senior      69           1003            8            1.0              8.0

# %% [markdown]
# ##### drop_duplicates()
#
# <p>Drops all duplicates from the current dataframe</p>

# %%
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1047            3            0.5              1.5    28
# 1         1003            8            1.0              8.0    69
# 2         1085            1            1.0              1.0    54
# 3         1072            8            0.5              4.0    53
# 4         1059            4            1.0              4.0    43
# 5         1013            0            1.0              0.0    37
# 6         1076            5            1.0              5.0    22
# 7         1095            3            1.0              3.0    60
# 8         1085            8            0.5              4.0    52
# 9         1012            9            1.0              9.0    59
#
#    loyalty_age_group    age_group
# 0    New Young Adult  Young Adult
# 1       Loyal Senior       Senior
# 2          New Adult        Adult
# 3        Loyal Adult        Adult
# 4        Loyal Adult        Adult
# 5          New Adult        Adult
# 6  Loyal Young Adult  Young Adult
# 7        Loyal Adult        Adult
# 8        Loyal Adult        Adult
# 9        Loyal Adult        Adult

# %%
customers_copy = customers.drop_duplicates('renewal_nbr').reset_index(drop = True)
customers_copy
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1047            3            0.5              1.5    28
# 1         1003            8            1.0              8.0    69
# 2         1085            1            1.0              1.0    54
# 3         1059            4            1.0              4.0    43
# 4         1013            0            1.0              0.0    37
# 5         1076            5            1.0              5.0    22
# 6         1012            9            1.0              9.0    59
#
#    loyalty_age_group    age_group
# 0    New Young Adult  Young Adult
# 1       Loyal Senior       Senior
# 2          New Adult        Adult
# 3        Loyal Adult        Adult
# 4          New Adult        Adult
# 5  Loyal Young Adult  Young Adult
# 6        Loyal Adult        Adult

# %% [markdown]
# <p>Thus the groupby operation allows you to rapidly make summary observations about the state of your entire dataset at flexible granularity. In one line above, we actually did something very complicated - that's the power of the dataframe. In fact, the process often consists of several iterative groupby operations, each revealing greater insight than the last - if you don't know where to start with a dataset, try a bunch of groupbys!</p>

# %% [markdown]
# ### Homework Excersise #1 - Find the Mean for the Red Sox <br>
# <p>Get total number of home runs and rbi's</p>

# %%
# step 1: Add a new column with the key 'Team' and all column values should be 'BOS'

# step 2: Group by the 'Team' column and get total home runs and rbi's

# Produce data for both 2017 and 2018
"""
TEAM    HR   RBI
----------------
BOS     144  538
"""
def load_data(filename, d=','):data = np.genfromtxt(filename,delimiter = d, skip_header =1, usecols = np.arange(0,24), invalid_raise = False, names = FIELDS, dtype = DATATYPES)

def make_team(row):
    hr = boston_sum2017['HR']+boston_sum2018['HR']
    rbi = boston_sum2017['RBI']+boston_sum2018['RBI']
    
print(boston17)
print(boston18)
    
boston17['Team'] = boston17.apply(make_team, axis = 1)
boston17[['Name', 'HR', 'RBI', 'Team']].loc[boston17['Team'] == 'Yes']
boston18['Team'] = boston18.apply(make_team, axis = 1)
boston18[['Name', 'HR', 'RBI', 'Team']].loc[boston18['Team'] == 'Yes']
# Out:
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B  ...    OPS  \
# 0    1   C   Christian Vazquez   26   99  345  324   43   94  18  ...  0.735
# 1    2  1B      Mitch Moreland   31  149  576  508   73  125  34  ...  0.769
# 2    3  2B      Dustin Pedroia   33  105  463  406   46  119  19  ...  0.760
# 3    4  SS     Xander Bogaerts   24  148  635  571   94  156  32  ...  0.746
# 4    5  3B       Rafael Devers   20   58  240  222   34   63  14  ...  0.819
# 5    6  LF   Andrew Benintendi   22  151  658  573   84  155  26  ...  0.776
# 6    7  CF  Jackie Bradley Jr.   27  133  541  482   58  118  19  ...  0.726
# 8    9  DH       J.D. Martinez   30  150  649  569  111  188  37  ...  0.629
# 9   10  MI          Brock Holt   30  109  367  321   41   89  18  ...  0.411
# 10  11   C   Christian Vazquez   27   80  269  251   24   52  10  ...  0.283
# 11  12  UT       Blake Swihart   26   82  207  192   28   44  10  ...  0.328
# 12  13  UT      Hanley Ramirez   34   44  195  177   25   45   7  ...  0.395
# 13  14  1B        Steve Pearce   35   50  165  136   19   38   8  ...  0.507
# 14  15  2B         Ian Kinsler   36   37  143  132   17   32   6  ...  0.311
# 15  16  SS         Tzu-Wei Lin   24   37   73   65   15   16   6  ...  0.415
# 16  17  UT          Sam Travis   24   19   38   36    5    8   3  ...  0.389
# 17  18  UT    Brandon Phillips   37    9   27   23    4    3   0  ...  0.261
# 18  19  2B      Dustin Pedroia   34    3   13   11    1    1   0  ...  0.091
# 19  20   C          Dan Butler   31    2    7    6    0    1   0  ...  0.167
#
#       OPS  OPS+   TB  GDP  HBP  SH  SF  IBB  Team
# 0   0.511    37   74    6    4   3   1    0  None
# 1   0.758   102  175   12    0   0   5    2  None
# 2   0.677    81  186   17    2   1   3    0  None
# 3   0.883   135  268   14    6   0   6    4  None
# 4   0.731    94  195    9    0   0   2    6  None
# 5   0.830   123  269    9    2   2   7    1  None
# 6   0.717    92  191    6   11   0   4    3  None
# 7   1.078   186  333    5    8   0   5    8  None
# 8   1.031   173  358   19    4   0   7   11  None
# 9   0.774   109  132    7    7   0   2    2  None
# 10  0.540    46   71    5    4   1   0    1  None
# 11  0.613    65   63    4    0   0   0    0  None
# 12  0.708    90   70    9    2   0   2    0  None
# 13  0.901   141   69    1    5   0   2    0  None
# 14  0.604    64   41    5    0   0   1    0  None
# 15  0.744   100   27    0    0   0   0    0  None
# 16  0.652    73   14    1    0   0   0    0  None
# 17  0.520    42    6    1    0   0   0    0  None
# 18  0.322    -7    1    0    0   0   0    0  None
# 19  0.310   -17    1    0    0   0   1    0  None
#
# [20 rows x 29 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-e77d9a7cbb24> in <module>
#      18 print(boston18)
#      19
# ---> 20 boston17['Team'] = boston17.apply(make_team, axis = 1)
#      21 boston17[['Name', 'HR', 'RBI', 'Team']].loc[boston17['Team'] == 'Yes']
#      22 boston18['Team'] = boston18.apply(make_team, axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     293
#     294             try:
# --> 295                 result = libreduction.compute_reduction(
#     296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-156-e77d9a7cbb24> in make_team(row)
#      12
#      13 def make_team(row):
# ---> 14     hr = boston_sum2017['HR']+boston_sum2018['HR']
#      15     rbi = boston_sum2017['RBI']+boston_sum2018['RBI']
#      16
#
# NameError: name 'boston_sum2017' is not defined

# %% [markdown]
# ## Find the average age of runners in the 2017 Boston Marathon

# %%
# mean = average
#pd.read_csv('../files/boston_marathon2017_edited.csv', sep = ',')
#runners = pd.DataFrame
#DataFrame.mean(axis = 0) 

#runners_2017 = total_age/26410
#print(mean)
marathon = pd.read_csv('../files/boston_marathon2017_edited.csv', sep = ',')
#marathon

#ages = 'age'/26410
#print('age')
#marathon

avg17 = ('age')/26410

print(avg17)

print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-575bd954f89d> in <module>
#      13 #marathon
#      14
# ---> 15 avg17 = ('age')/26410
#      16
#      17 print(avg17)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
